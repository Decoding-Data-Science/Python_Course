# %% [markdown]
# <a href="https://colab.research.google.com/github/Decoding-Data-Science/Python_Course/blob/main/Python_Fast_track/Your_First_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")

# %%
print("<<type your name here>>")
